# %%
import pandas as pd

# %%
df = pd.read_csv("../data/transactions.csv")

# %%
df.head(3)
# Out:
#    Unnamed: 0     Transaction Date  \
# 0           1  2022-05-01 00:00:00
# 1           2  2022-05-01 00:00:00
# 2           3  2022-05-02 00:00:00
#
#                                          Description  \
# 0     TO TRANSFER-UPI/DR/212184145933/NAIVEDYA/PY...
# 1     TO TRANSFER-UPI/DR/212176631177/NAIVEDYA/PY...
# 2     TO TRANSFER-UPI/DR/212298919584/Zerodha/ICI...
#
#            Ref No./Cheque No  Debit  Credit   Balance
# 0  TRANSFER TO 4692675162099   30.0     0.0  1,655.78
# 1  TRANSFER TO 4692666162090   10.0     0.0  1,645.78
# 2  TRANSFER TO 5097543162099  273.0     0.0  1,372.78

# %%
df.shape
# Out:
# (53, 7)

# %% [markdown]
# ## How much I got?

# %%
df[df["Credit"]!=0.0]
# Out:
#     Unnamed: 0     Transaction Date  \
# 15          16  2022-05-08 00:00:00
# 18          19  2022-05-09 00:00:00
# 22          23  2022-05-11 00:00:00
# 23          24  2022-05-11 00:00:00
# 28          29  2022-05-13 00:00:00
# 32          33  2022-05-13 00:00:00
# 33          34  2022-05-13 00:00:00
# 35          36  2022-05-13 00:00:00
# 48          49  2022-05-18 00:00:00
#
#                                           Description  \
# 15     BY TRANSFER-UPI/CR/212848587722/SHOBHA M/UB...
# 18     BY TRANSFER-PFM 522801492162 Fee Concession...
# 22     BY TRANSFER-UPI/CR/213112651834/Laxmikan/SB...
# 23     BY TRANSFER-UPI/CR/213194527775/HARSHA  AC/...
# 28     BY TRANSFER-UPI/CR/213306710022/Laxmikan/SB...
# 32     BY TRANSFER-UPI/CR/213362611074/HARSHA  AC/...
# 33     BY TRANSFER-UPI/CR/213313258151/Laxmikan/SB...
# 35     BY TRANSFER-UPI/CR/213374905024/SATISH G/CN...
# 48     BY TRANSFER-UPI/CR/213859433679/SATISH G/CN...
#
# ...

# %% [markdown]
# ## How much I sent?

# %%
df[df["Debit"]!=0.0]
# Out:
#     Unnamed: 0     Transaction Date  \
# 0            1  2022-05-01 00:00:00
# 1            2  2022-05-01 00:00:00
# 2            3  2022-05-02 00:00:00
# 3            4  2022-05-02 00:00:00
# 4            5  2022-05-02 00:00:00
# 5            6  2022-05-02 00:00:00
# 6            7  2022-05-02 00:00:00
# 7            8  2022-05-03 00:00:00
# 8            9  2022-05-03 00:00:00
# 9           10  2022-05-04 00:00:00
# 10          11  2022-05-05 00:00:00
# 11          12  2022-05-06 00:00:00
# 12          13  2022-05-07 00:00:00
# 13          14  2022-05-07 00:00:00
# 14          15  2022-05-07 00:00:00
# 16          17  2022-05-08 00:00:00
# 17          18  2022-05-09 00:00:00
# 19          20  2022-05-11 00:00:00
# 20          21  2022-05-11 00:00:00
# 21          22  2022-05-11 00:00:00
# 24          25  2022-05-11 00:00:00
# 25          26  2022-05-12 00:00:00
# 26          27  2022-05-12 00:00:00
# 27          28  2022-05-13 00:00:00
# 29          30  2022-05-13 00:00:00
# ...
